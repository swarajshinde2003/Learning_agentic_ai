# %%
print("sdfghjk")
# Out:
# sdfghjk

# %%
import os 
key = os.getenv("OLLAMA_API_KEY")
print(key)
# Out:
# 1a937638898b43c394ee988c20dd2eb3.d0SV0tD-xdu0KlufGQVb0KMt

# %%
import os
from langchain_openai import ChatOpenAI

llm= ChatOpenAI(
    api_key=os.getenv("OLLAMA_API_KEY"),
    model  = "gpt-oss:120b",
    base_url= "https://ollama.com/v1",
    temperature= 0.2
)

llm.invoke("what is car")
# Out:
# AIMessage(content='**A car (short for “automobile”) is a self‑propelled road vehicle designed to transport people (and sometimes cargo) on streets and highways.**  \n\n### Core characteristics\n| Feature | Typical description |\n|---------|----------------------|\n| **Power source** | Most modern cars use internal‑combustion engines that burn gasoline or diesel, but many run on electricity (BEVs), hybrid systems (combustion\u202f+\u202felectric), hydrogen fuel cells, or alternative fuels. |\n| **Number of wheels** | Four wheels (two front, two rear) – the most common layout. |\n| **Seating capacity** | Usually 2‑5 passengers; larger models (minivans, SUVs) can seat 7‑8. |\n| **Control** | Driver sits behind a steering wheel (or a steering column in some electric‑steering designs) and uses pedals (accelerator, brake, clutch in manual transmissions) to control speed and direction. |\n| **Legal classification** | In most jurisdictions a “car” falls under the vehicle class *passenger aut
# ...
